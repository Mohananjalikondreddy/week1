# %%
a = input('Enter a string :- ')
state = 0
for i in a:
    if state == 0:
        if i == 'a':
            state = 1
        elif i == 'b':
            state = 2
        else:
            print('error')
        continue
    elif state == 1:
        if i == 'a':
            state = 3
        elif i == 'b':
            state = 2
        else:
            print('error')
        continue
    elif state == 2:
        if i == 'a':
            state = 1
        elif i == 'b':
            state = 4
        else:
            print('error')
        continue
    elif state == 3:
        if i == 'a':
            state = 3
        elif i == 'b':
            state = 2
        else:
            print('error')
        continue
    elif state == 4:
        if i == 'a':
            state = 1
        elif i == 'b':
            state = 4
        else:
            print('error')
        continue
if state == 3 or state == 4:
    print('string accepted')
else:
    print('string not accepted')
# Out:
# Enter a string :- aabb
# string accepted
